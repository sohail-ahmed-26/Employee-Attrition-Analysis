# %% [markdown]
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:35px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:20px;">
#
# <h1 style="
#     font-size:36px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:3px;
#     margin:0;
#     text-transform:uppercase;
#     text-shadow:
#         0 1px 0 #0a1a22,
#         0 2px 0 #091820,
#         0 3px 0 #071117,
#         0 4px 0 #050d12,
#         0 8px 15px rgba(0,0,0,0.6),
#         0 12px 25px rgba(0,0,0,0.5);
# ">
# EMPLOYEE ATTRITION ANALYTICS
# </h1>
#
# </div>

# %% [markdown]
# <div align="center" style="background-color:#0f2027; padding:20px; border-radius:10px; border:2px solid #00c6ff;">
#
# <h1 style="color:white; margin-bottom:10px;">About Author</h1>
#
# <a href="https://www.sak.kesug.com">
# <img src="https://avatars.githubusercontent.com/sohail-ahmed-26"
# width="120"
# style="border-radius:50%; border:3px solid #00c6ff;">
# </a>
#
# <h2 style="color:white; margin-top:15px;">Mr. Sohail Ahmed</h2>
#
# <p style="color:#cfd8dc;">
# <span style="color:#00e5ff;"><b>Data Scientist / ML Engineer</b></span><br>
# BS Telecommunication
# </p>
#
# <p>
# <a href="https://youtube.com/@sohailahmed-k4k?si=uZ7KjZ_0qTkNekgp">
# <img width="40" src="https://img.icons8.com/color/48/youtube-play.png">
# </a>
# <a href="https://x.com/ahmed241126">
# <img width="40" src="https://img.icons8.com/dotty/80/x.png">
# </a>
# <a href="https://www.linkedin.com/in/sohail-ahmed-devsil">
# <img width="40" src="https://img.icons8.com/color/48/linkedin.png">
# </a>
# <a href="https://github.com/sohail-ahmed-26">
# <img width="40" src="https://img.icons8.com/ios-glyphs/50/github.png">
# </a>
# <a href="https://www.kaggle.com/sohail2411126">
# <img width="40" src="https://img.icons8.com/clouds/100/kaggle.png">
# </a>
# </p>
#
# <p>
# <a href="https://www.sak.kesug.com"
# style="color:#00c6ff; text-decoration:none; border:1px solid #00c6ff; padding:6px 15px; border-radius:6px;">
# Portfolio Site
# </a>
# </p>
#
# </div>

# %% [markdown]
# <div style="background:#0b1d26; padding:60px 0;">
#
# <div style="
#   position:relative;
#   max-width:1000px;
#   margin:auto;
#   padding:60px;
#   border-radius:18px;
#   backdrop-filter:blur(18px);
#   background:rgba(255,255,255,0.05);
#   border:1px solid rgba(255,255,255,0.1);
#   box-shadow:0 30px 60px rgba(0,0,0,0.5);
#   font-family:'Segoe UI',sans-serif;
#   color:#ffffff;
# ">
#
# <h1 style="
#   text-align:center;
#   font-size:40px;
#   font-weight:800;
#   letter-spacing:2px;
#   margin-bottom:10px;
#   text-shadow:0 2px 0 #0a1a22, 0 4px 10px rgba(0,0,0,0.6);
# ">
# TABLE OF CONTENTS
# </h1>
#
# <h2 style="
#   text-align:center;
#   font-size:18px;
#   font-weight:400;
#   color:#cfd8dc;
#   margin-bottom:45px;
#   letter-spacing:3px;
#   text-transform:uppercase;
# ">
# Employee Attrition Prediction Dashboard
# </h2>
#
# <ol style="list-style:none; padding-left:0;">
#
# <li style="margin:20px 0; padding:16px 22px; border-left:4px solid #00c6ff; background:rgba(255,255,255,0.06); border-radius:10px;">Project Overview</li>
#
# <li style="margin:20px 0; padding:16px 22px; border-left:4px solid #00c6ff; background:rgba(255,255,255,0.06); border-radius:10px;">Business Problem</li>
#
# <li style="margin:20px 0; padding:16px 22px; border-left:4px solid #00c6ff; background:rgba(255,255,255,0.06); border-radius:10px;">Project Objectives</li>
#
# <li style="margin:20px 0; padding:16px 22px; border-left:4px solid #00c6ff; background:rgba(255,255,255,0.06); border-radius:10px;">
# Dataset Information
# <ul style="margin-top:12px; padding-left:25px; color:#e0f7fa;">
# <li>4.1 Dataset Source</li>
# <li>4.2 Dataset Description</li>
# <li>4.3 Features Overview</li>
# </ul>
# </li>
#
# <li style="margin:20px 0; padding:16px 22px; border-left:4px solid #00c6ff; background:rgba(255,255,255,0.06); border-radius:10px;">
# Data Cleaning
# <ul style="margin-top:12px; padding-left:25px; color:#e0f7fa;">
# <li>Checking Missing Values</li>
# <li>Removing Duplicates</li>
# <li>Handling Data Types</li>
# <li>Outlier Detection & Treatment</li>
# </ul>
# </li>
#
# <li style="margin:20px 0; padding:16px 22px; border-left:4px solid #00c6ff; background:rgba(255,255,255,0.06); border-radius:10px;">
# Exploratory Data Analysis (EDA)
# <ul style="margin-top:12px; padding-left:25px; color:#e0f7fa;">
# <li>Attrition Count & Percentage</li>
# <li>Department-wise Attrition</li>
# <li>Salary Analysis</li>
# <li>Job Satisfaction Analysis</li>
# <li>Work-Life Balance</li>
# </ul>
# </li>
#
# <li style="margin:20px 0; padding:16px 22px; border-left:4px solid #00c6ff; background:rgba(255,255,255,0.06); border-radius:10px;">
# Statistical Analysis
# </li>
#
# <li style="margin:20px 0; padding:16px 22px; border-left:4px solid #00c6ff; background:rgba(255,255,255,0.06); border-radius:10px;">
# Data Visualization
# </li>
#
# <li style="margin:20px 0; padding:16px 22px; border-left:4px solid #00c6ff; background:rgba(255,255,255,0.06); border-radius:10px;">
# Business Insights
# </li>
#
# <li style="margin:20px 0; padding:16px 22px; border-left:4px solid #00c6ff; background:rgba(255,255,255,0.06); border-radius:10px;">
# Recommendations
# </li>
#
# </ol>

# %% [markdown]
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:30px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:20px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
# PROJECT OVERVIEW
# </h2>
#
# </div>
#
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:15px;">
#
# <ul style="color:#cfd8dc; font-size:16px; line-height:1.8;">
#
# <li><b style="color:#ffffff;">Project Purpose:</b>
# This project focuses on analyzing employee attrition trends within an organization to understand why employees leave and what factors influence their decision.</li>
#
# <li><b style="color:#ffffff;">Dataset Used:</b>
# The analysis is performed using the IBM HR Analytics Attrition dataset, which contains employee demographic, salary, job satisfaction, and work-related information.</li>
#
# <li><b style="color:#ffffff;">Core Analysis Performed:</b>
# The project includes data cleaning, exploratory data analysis (EDA), statistical analysis, and visualization techniques to identify meaningful patterns.</li>
#
# <li><b style="color:#ffffff;">Key Variables Analyzed:</b>
# Monthly income, department, job satisfaction, work-life balance, tenure (years at company), and attrition status.</li>
#
# <li><b style="color:#ffffff;">Business Impact:</b>
# The insights generated help HR departments reduce turnover costs, improve employee retention strategies, and enhance workforce stability.</li>
#
# <li><b style="color:#ffffff;">Final Outcome:</b>
# Actionable recommendations are provided to support data-driven HR decision-making and long-term organizational growth.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:30px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:20px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
# BUSINESS PROBLEM
# </h2>
#
# </div>
#
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:15px;">
#
# <ul style="color:#cfd8dc; font-size:16px; line-height:1.8;">
#
# <li><b style="color:#ffffff;">Increasing Employee Turnover:</b>
# The organization is experiencing a rising number of employees leaving the company, leading to instability in workforce planning.</li>
#
# <li><b style="color:#ffffff;">High Operational Costs:</b>
# Employee attrition results in increased recruitment expenses, training costs, and productivity loss.</li>
#
# <li><b style="color:#ffffff;">Lack of Clear Insights:</b>
# HR management does not have a data-driven understanding of which departments or employee segments are most affected.</li>
#
# <li><b style="color:#ffffff;">Unidentified Key Factors:</b>
# It is unclear whether salary, job satisfaction, work-life balance, tenure, or other variables significantly influence employee attrition.</li>
#
# <li><b style="color:#ffffff;">Need for Strategic Decisions:</b>
# The organization requires analytical insights to design effective retention strategies and improve employee engagement.</li>
#
# <li><b style="color:#ffffff;">Business Objective:</b>
# To analyze historical employee data and uncover patterns that explain attrition trends, enabling data-backed HR decision-making.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:30px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:20px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
# PROJECT OBJECTIVES
# </h2>
#
# </div>
#
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:15px;">
#
# <ul style="color:#cfd8dc; font-size:16px; line-height:1.9;">
#
# <li><b style="color:#ffffff;">Understand Attrition Patterns:</b>
# To analyze overall employee attrition trends and calculate the attrition rate within the organization.</li>
#
# <li><b style="color:#ffffff;">Identify Key Influencing Factors:</b>
# To determine how salary, job satisfaction, work-life balance, tenure, and department impact employee turnover.</li>
#
# <li><b style="color:#ffffff;">Department-Level Analysis:</b>
# To identify which departments have the highest attrition and investigate possible reasons.</li>
#
# <li><b style="color:#ffffff;">Compare Employees (Stayed vs Left):</b>
# To compare income levels, years at company, and satisfaction scores between employees who stayed and those who left.</li>
#
# <li><b style="color:#ffffff;">Perform Statistical Evaluation:</b>
# To apply statistical measures such as mean, median, standard deviation, correlation, and hypothesis testing for deeper insights.</li>
#
# <li><b style="color:#ffffff;">Generate Data-Driven Insights:</b>
# To convert analytical findings into meaningful business insights for HR decision-making.</li>
#
# <li><b style="color:#ffffff;">Provide Strategic Recommendations:</b>
# To suggest actionable strategies that can help reduce employee turnover and improve retention.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# <!-- MAIN HEADING -->
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:40px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:10px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
# DATASET INFORMATION
# </h2>
#
# </div>
#
# <!-- SUBSECTION -->
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:15px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 4.1 Dataset Source
# </h3>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:16px;">
# The dataset used in this project is the <b style="color:#ffffff;">IBM HR Analytics Employee Attrition & Performance Dataset</b>.
# It is publicly available on Kaggle and is widely used for HR analytics and employee turnover analysis projects.
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:16px;">
# <b style="color:#ffffff;">Source Platform:</b> Kaggle<br>
# <b style="color:#ffffff;">Dataset Name:</b> IBM HR Analytics Attrition Dataset<br>
# <b style="color:#ffffff;">Access Link:</b>
# <a href="https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset"
#    style="color:#00c6ff; text-decoration:none;">
# https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset
# </a>
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:16px;">
# This dataset contains employee-level information including demographic details, salary, job role, satisfaction levels, tenure, and attrition status, enabling comprehensive workforce analysis.
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 4.2 Dataset Description
# </h3>
#
# <table style="width:100%; border-collapse:collapse; margin-top:15px; font-family:Segoe UI, sans-serif;">
#
# <tr style="background-color:#112b36; color:#ffffff;">
# <th style="padding:12px; border:1px solid #00c6ff; text-align:left;">Category</th>
# <th style="padding:12px; border:1px solid #00c6ff; text-align:left;">Details</th>
# </tr>
#
# <tr style="color:#cfd8dc;">
# <td style="padding:12px; border:1px solid #00c6ff;"><b>Dataset Name</b></td>
# <td style="padding:12px; border:1px solid #00c6ff;">IBM HR Analytics Employee Attrition Dataset</td>
# </tr>
#
# <tr style="color:#cfd8dc;">
# <td style="padding:12px; border:1px solid #00c6ff;"><b>Total Records</b></td>
# <td style="padding:12px; border:1px solid #00c6ff;">1,470 Employee Records</td>
# </tr>
#
# <tr style="color:#cfd8dc;">
# <td style="padding:12px; border:1px solid #00c6ff;"><b>Total Attributes</b></td>
# <td style="padding:12px; border:1px solid #00c6ff;">35 Columns (Features)</td>
# </tr>
#
# <tr style="color:#cfd8dc;">
# <td style="padding:12px; border:1px solid #00c6ff;"><b>Dataset Type</b></td>
# <td style="padding:12px; border:1px solid #00c6ff;">Structured Tabular Dataset (CSV Format)</td>
# </tr>
#
# <tr style="color:#cfd8dc;">
# <td style="padding:12px; border:1px solid #00c6ff;"><b>Domain</b></td>
# <td style="padding:12px; border:1px solid #00c6ff;">Human Resource Analytics</td>
# </tr>
#
# <tr style="color:#cfd8dc;">
# <td style="padding:12px; border:1px solid #00c6ff;"><b>Target Variable</b></td>
# <td style="padding:12px; border:1px solid #00c6ff;">Attrition (Yes / No)</td>
# </tr>
#
# <tr style="color:#cfd8dc;">
# <td style="padding:12px; border:1px solid #00c6ff;"><b>Data Categories</b></td>
# <td style="padding:12px; border:1px solid #00c6ff;">
# Demographic, Job-related, Financial, Satisfaction, Behavioral Attributes
# </td>
# </tr>
#
# <tr style="color:#cfd8dc;">
# <td style="padding:12px; border:1px solid #00c6ff;"><b>Purpose</b></td>
# <td style="padding:12px; border:1px solid #00c6ff;">
# Analyze attrition trends, identify influencing factors, support HR decision-making
# </td>
# </tr>
#
# </table>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 4.3 Features Overview
# </h3>
#
# <table style="width:100%; border-collapse:collapse; margin-top:15px; font-family:Segoe UI, sans-serif;">
#
# <tr style="background-color:#112b36; color:#ffffff;">
# <th style="padding:12px; border:1px solid #00c6ff; text-align:left;">Feature Category</th>
# <th style="padding:12px; border:1px solid #00c6ff; text-align:left;">Included Variables</th>
# <th style="padding:12px; border:1px solid #00c6ff; text-align:left;">Purpose in Analysis</th>
# </tr>
#
# <tr style="color:#cfd8dc;">
# <td style="padding:12px; border:1px solid #00c6ff;"><b>Target Variable</b></td>
# <td style="padding:12px; border:1px solid #00c6ff;">Attrition</td>
# <td style="padding:12px; border:1px solid #00c6ff;">Identify whether an employee left the organization</td>
# </tr>
#
# <tr style="color:#cfd8dc;">
# <td style="padding:12px; border:1px solid #00c6ff;"><b>Demographic Features</b></td>
# <td style="padding:12px; border:1px solid #00c6ff;">
# Age, Gender, Education, EducationField, MaritalStatus
# </td>
# <td style="padding:12px; border:1px solid #00c6ff;">
# Analyze personal background impact on attrition
# </td>
# </tr>
#
# <tr style="color:#cfd8dc;">
# <td style="padding:12px; border:1px solid #00c6ff;"><b>Job-Related Features</b></td>
# <td style="padding:12px; border:1px solid #00c6ff;">
# Department, JobRole, JobLevel, BusinessTravel, YearsAtCompany,
# YearsInCurrentRole, YearsWithCurrManager, TotalWorkingYears
# </td>
# <td style="padding:12px; border:1px solid #00c6ff;">
# Identify role and department-level attrition patterns
# </td>
# </tr>
#
# <tr style="color:#cfd8dc;">
# <td style="padding:12px; border:1px solid #00c6ff;"><b>Financial Features</b></td>
# <td style="padding:12px; border:1px solid #00c6ff;">
# MonthlyIncome, DailyRate, HourlyRate, MonthlyRate,
# PercentSalaryHike, StockOptionLevel
# </td>
# <td style="padding:12px; border:1px solid #00c6ff;">
# Examine salary influence on employee turnover
# </td>
# </tr>
#
# <tr style="color:#cfd8dc;">
# <td style="padding:12px; border:1px solid #00c6ff;"><b>Satisfaction & Performance</b></td>
# <td style="padding:12px; border:1px solid #00c6ff;">
# JobSatisfaction, EnvironmentSatisfaction, RelationshipSatisfaction,
# WorkLifeBalance, PerformanceRating, JobInvolvement
# </td>
# <td style="padding:12px; border:1px solid #00c6ff;">
# Evaluate impact of employee engagement and satisfaction
# </td>
# </tr>
#
# <tr style="color:#cfd8dc;">
# <td style="padding:12px; border:1px solid #00c6ff;"><b>Other Behavioral Features</b></td>
# <td style="padding:12px; border:1px solid #00c6ff;">
# OverTime, DistanceFromHome, TrainingTimesLastYear, NumCompaniesWorked
# </td>
# <td style="padding:12px; border:1px solid #00c6ff;">
# Study behavioral and experience-related attrition factors
# </td>
# </tr>
#
# </table>
#
# </div>

# %% [markdown]
# <!-- MAIN HEADING -->
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:40px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:10px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
# 5. DATA LOADING & INITIAL EXPLORATION
# </h2>
#
# </div>
#
#
# <!-- SUBSECTION 5.1 -->
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 5.1 Importing Required Libraries
# </h3>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:16px;">
# Before loading and analyzing the dataset, essential Python libraries are imported to support data manipulation, visualization, and statistical analysis.
# </p>
#
# <ul style="color:#cfd8dc; font-size:16px; line-height:1.9;">
#
# <li><b style="color:#ffffff;">Pandas:</b> Used for data loading, cleaning, and manipulation.</li>
#
# <li><b style="color:#ffffff;">NumPy:</b> Used for numerical computations and array operations.</li>
#
# <li><b style="color:#ffffff;">Matplotlib & Seaborn:</b> Used for data visualization and graphical analysis.</li>
#
# <li><b style="color:#ffffff;">SciPy / Statistical Libraries:</b> Used for hypothesis testing and statistical evaluation.</li>
#
# </ul>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:16px;">
# These libraries provide the foundation for performing structured data analysis and extracting meaningful insights from the dataset.
# </p>
#
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as state
import seaborn as sns
import plotly.express as px

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 5.2 Loading the Dataset
# </h3>
#
# </div>

# %%
df = pd.read_csv("./employee_atrition.csv")

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 5.3 Previewing First Rows(head)
# </h3>
#
# </div>

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 5.4 Dataset Shape & Structure
# </h3>
#
# </div>

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   str
#  2   BusinessTravel            1470 non-null   str
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   str
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   str
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   str
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# <!-- MAIN HEADING -->
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:40px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:10px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
# DATA CLEANING
# </h2>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 6.1 Checking Missing Value
# </h3>
#
# </div>

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 6.2 Checking Duplicate
# </h3>
#
# </div>

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 6.3 Outliers Detection & Treatment
# </h3>
#
# </div>

# %%
Q1 = df["MonthlyIncome"].quantile(0.25)
Q3 = df["MonthlyIncome"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
df=df[(df["MonthlyIncome"] >= lower) & 
              (df["MonthlyIncome"] <= upper)]
print("Max:",df["MonthlyIncome"].max())
import plotly.express as px
fig = px.box(df, y="MonthlyIncome")
fig.show()
# Out:
# Max: 16555

# %% [markdown]
# <!-- MAIN HEADING -->
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:40px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:10px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
# EXPLORATORY DATA ANALYSIS
# </h2>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 7.1 Attrition Count
# </h3>
#
# </div>

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     1124
# Yes     232
# Name: count, dtype: int64

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 7.2 Attrition Percentage
# </h3>
#
# </div>

# %%
df["Attrition"].value_counts()/1266*10
# Out:
# Attrition
# No     8.878357
# Yes    1.832543
# Name: count, dtype: float64

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 7.3 Department-Wise Attrition
# </h3>
#
# </div>

# %%
df.groupby("Department")["Attrition"].value_counts()
# Out:
# Department              Attrition
# Human Resources         No            42
#                         Yes           12
# Research & Development  No           751
#                         Yes          130
# Sales                   No           331
#                         Yes           90
# Name: count, dtype: int64

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 7.4 Monthly Income Distribution
# </h3>
#
# </div>

# %%
df['MonthlyIncome'].hist()
# Out:
# <Axes: >

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 7.5 Salary VS Attrition
# </h3>
#
# </div>

# %%
df.groupby("Attrition")["MonthlyIncome"].value_counts()
# Out:
# Attrition  MonthlyIncome
# No         5562             3
#            2559             3
#            2451             3
#            6347             3
#            3452             3
#                            ..
# Yes        4508             1
#            9582             1
#            10482            1
#            2625             1
#            2321             1
# Name: count, Length: 1276, dtype: int64

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 7.6 Salary VS Department
# </h3>
#
# </div>

# %%
df.groupby("Department")["MonthlyIncome"].value_counts()
# Out:
# Department       MonthlyIncome
# Human Resources  3195             1
#                  9756             1
#                  3423             1
#                  6347             1
#                  2064             1
#                                  ..
# Sales            2308             1
#                  4859             1
#                  4306             1
#                  9924             1
#                  5993             1
# Name: count, Length: 1280, dtype: int64

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 7.7 Job Satisfaction Distribution
# </h3>
#
# </div>

# %%
df["JobSatisfaction"].value_counts()
# Out:
# JobSatisfaction
# 4    427
# 3    407
# 1    264
# 2    258
# Name: count, dtype: int64

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 7.8 JobSatisfaction VS Attrition
# </h3>
#
# </div>

# %%
df.groupby("Attrition")["JobSatisfaction"].value_counts()
# Out:
# Attrition  JobSatisfaction
# No         4                  376
#            3                  335
#            2                  214
#            1                  199
# Yes        3                   72
#            1                   65
#            4                   51
#            2                   44
# Name: count, dtype: int64

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 7.9 Work-Life Balance VS Attrition
# </h3>
#
# </div>

# %%
df.groupby("Attrition")["WorkLifeBalance"].value_counts()
# Out:
# Attrition  WorkLifeBalance
# No         3                  702
#            2                  257
#            4                  113
#            1                   52
# Yes        3                  122
#            2                   58
#            4                   27
#            1                   25
# Name: count, dtype: int64

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 7.10 Year At Company VS Attrition
# </h3>
#
# </div>

# %%
df.groupby("Attrition")["YearsAtCompany"].value_counts()
# Out:
# Attrition  YearsAtCompany
# No         5                 166
#            1                 104
#            3                 103
#            10                 96
#            2                  95
#            4                  87
#            7                  74
#            9                  69
#            8                  68
#            6                  66
#            11                 29
#            0                  27
#            13                 21
#            15                 19
#            20                 17
#            12                 13
#            14                 13
#            16                 10
#            18                 10
#            17                  8
#            19                  7
#            22                  6
#            21                  5
#            33                  2
#            24                  2
#            25                  2
#            37                  1
# ...

# %% [markdown]
# <!-- MAIN HEADING -->
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:40px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:10px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
# STATISTICAL ANALYSIS
# </h2>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 8.1 Mean Salary (Attrition Yes VS No)
# </h3>
#
# </div>

# %%
df["MonthlyIncome"].mean()
# Out:
# np.float64(5502.763274336283)

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 8.2 Median Years At Company
# </h3>
#
# </div>

# %%
df["YearsAtCompany"].median()
# Out:
# np.float64(5.0)

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 8.3 Standard Deviation Of Income
# </h3>
#
# </div>

# %%
df["MonthlyIncome"].std()
# Out:
# np.float64(3319.8518751701704)

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 8.4 Hypothesis Testing
# </h3>
#
# </div>

# %%
from scipy import stats
group1 = df.loc[df["Attrition"]=="Yes", "MonthlyIncome"].dropna()
group2 = df.loc[df["Attrition"]=="No",  "MonthlyIncome"].dropna()
t, p = stats.ttest_ind(group1, group2, equal_var=False, nan_policy='omit')  # Welch's t-test
print("t=", t, "p=", p)
# Out:
# t= -5.694496934949914 p= 2.5526903444747516e-08

# %% [markdown]
# <!-- MAIN HEADING -->
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:40px;">
#
# <h2 style="
#     font-size:30px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     margin-bottom:10px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
# DATA VISUALIZATION
# </h2>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 9.1 Bar Charts
# </h3>
#
# </div>

# %%
import plotly.express as px

counts = df['Attrition'].value_counts().reset_index()
counts.columns = ['Attrition', 'Count']
plt.figure(figsize=(8,6))
fig = px.bar(counts,
             x='Attrition',
             y='Count',
             title='Attrition Distribution')

fig.show()

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:20px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:15px;">
#
# <p style="
#     color:#ffffff;
#     font-family:Segoe UI, sans-serif;
#     font-size:16px;
#     font-weight:700;">
# Conclusion:
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:15px;">
# The bar chart indicates that the majority of employees have remained in the organization, while a smaller proportion has left.
# This suggests that overall workforce retention is stable; however, the presence of employee attrition highlights the need for further analysis to identify the underlying factors contributing to turnover.
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 9.2 Histogram
# </h3>
#
# </div>

# %%
plt.figure(figsize=(8,6))
plt.figure()
plt.hist(df['Age'], bins=15)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution of Employees')
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:20px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:15px;">
#
# <p style="
#     color:#ffffff;
#     font-family:Segoe UI, sans-serif;
#     font-size:16px;
#     font-weight:700;">
# Conclusion:
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:15px;">
# The histogram shows that the majority of employees fall within the age range of approximately 30 to 40 years.
# The distribution appears slightly right-skewed, indicating fewer employees in the higher age groups.
# This suggests that the organization primarily consists of mid-career professionals, with comparatively fewer very young or senior employees.
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 9.2 Boxplot
# </h3>
#
# </div>

# %%
plt.figure(figsize=(8,6))
plt.figure()
plt.boxplot(df['MonthlyIncome'])
plt.ylabel('Monthly Income')
plt.title('Box Plot of Monthly Income')
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:20px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:15px;">
#
# <p style="color:#ffffff; font-family:Segoe UI, sans-serif; font-size:16px; font-weight:700;">
# Conclusion:
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:15px;">
# The box plot of Monthly Income indicates the presence of several high-value outliers above the upper whisker.
# This suggests that while most employees earn within a moderate salary range, a small number of employees receive significantly higher compensation.
# The distribution appears right-skewed, highlighting income inequality within the organization.
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 9.3 Pie Chart
# </h3>
#
# </div>

# %%
attrition_counts = df['Attrition'].value_counts()
plt.figure(figsize=(8,6))
plt.figure()
plt.pie(attrition_counts, labels=attrition_counts.index, autopct='%1.1f%%')
plt.title('Attrition Distribution')
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:20px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:15px;">
#
# <p style="color:#ffffff; font-family:Segoe UI, sans-serif; font-size:16px; font-weight:700;">
# Conclusion:
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:15px;">
# The pie chart shows that the majority of employees remain in the organization, while a smaller percentage have left.
# This indicates a relatively stable workforce, although employee attrition is still present and requires further analysis.
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 9.5 Correlation Heatmap
# </h3>
#
# </div>

# %%
plt.figure(figsize=(8,6))
corr = df.corr(numeric_only = True)
fig = px.imshow(
    corr,
    text_auto= '.2f',
    color_continuous_scale = 'RdBu',
    title = 'Correlation Heatmap'
)
fig.update_layout(width=700, height=700)
fig.update_traces(text=corr.round(2), texttemplate="%{text}")
fig.show()

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:20px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:15px;">
#
# <p style="color:#ffffff; font-family:Segoe UI, sans-serif; font-size:16px; font-weight:700;">
# Conclusion:
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:15px;">
# The correlation analysis indicates that most variables have weak to moderate relationships with each other, suggesting limited multicollinearity within the dataset.
# Strong positive correlations are observed among experience-related variables such as TotalWorkingYears, YearsAtCompany, YearsInCurrentRole, and YearsWithCurrManager, which is logically consistent.
#
# MonthlyIncome also shows a positive correlation with JobLevel and TotalWorkingYears, indicating that salary generally increases with experience and position level.
# However, Attrition does not exhibit a strong linear correlation with most numerical variables, suggesting that employee turnover is influenced by multiple combined factors rather than a single dominant variable.
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <h3 style="
#     color:#00e5ff;
#     font-family:Segoe UI, sans-serif;
#     font-size:20px;
#     font-weight:700;">
# 9.6 Department-Wise Attrition Chart
# </h3>
#
# </div>

# %%
dept_attrition = pd.crosstab(df['Department'], df['Attrition'])

plt.figure(figsize=(8,6))

ax = dept_attrition.plot(kind='bar')

plt.xlabel('Department')
plt.ylabel('Number of Employees')
plt.title('Department-wise Attrition', fontweight='bold')

plt.xticks(rotation=30)   # rotate labels
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#0f2027;
#             padding:20px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:15px;">
#
# <p style="color:#ffffff; font-family:Segoe UI, sans-serif; font-size:16px; font-weight:700;">
# Conclusion:
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:15px;">
# The department-wise attrition analysis reveals noticeable differences in employee turnover across departments.
# Certain departments exhibit higher attrition compared to others, indicating potential workplace challenges specific to those areas.
#
# This suggests that employee retention strategies should be department-focused rather than organization-wide, allowing HR to address department-specific concerns such as workload, job satisfaction, or management practices.
# </p>
#
# </div>

# %% [markdown]
# <!-- PHASE 5: BUSINESS INSIGHTS -->
#
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:40px;">
#
# <h2 style="
#     font-size:28px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
# BUSINESS INSIGHTS
# </h2>
#
# </div>
#
#
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <!-- Q1 -->
# <p style="color:#ffffff; font-size:17px; font-weight:700;">
# 1. Which department has the highest attrition?
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:15px;">
# The analysis shows that certain departments experience higher attrition compared to others.
# This indicates that employee turnover is not evenly distributed across the organization.
# Departments with higher attrition may be facing workload pressure, role dissatisfaction, or limited career growth opportunities.
# </p>
#
# <hr style="border:1px solid #00c6ff;">
#
# <!-- Q2 -->
# <p style="color:#ffffff; font-size:17px; font-weight:700;">
# 2. Do low salary employees leave more?
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:15px;">
# Salary distribution analysis suggests that employees with lower monthly income show relatively higher attrition rates.
# This indicates that compensation plays an important role in employee retention.
# Competitive salary structures may reduce turnover among lower income groups.
# </p>
#
# <hr style="border:1px solid #00c6ff;">
#
# <!-- Q3 -->
# <p style="color:#ffffff; font-size:17px; font-weight:700;">
# 3. Does job satisfaction affect attrition?
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:15px;">
# Employees with lower job satisfaction levels tend to leave the organization more frequently.
# This suggests that workplace environment, recognition, and employee engagement significantly impact retention.
# Improving job satisfaction can directly reduce attrition.
# </p>
#
# <hr style="border:1px solid #00c6ff;">
#
# <!-- Q4 -->
# <p style="color:#ffffff; font-size:17px; font-weight:700;">
# 4. Does work-life balance impact attrition?
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:15px;">
# The analysis indicates that employees with poor work-life balance are more likely to leave the organization.
# Excessive overtime and work pressure can contribute to higher attrition rates.
# Promoting flexible work policies may improve employee retention.
# </p>
#
# <hr style="border:1px solid #00c6ff;">
#
# <!-- Q5 -->
# <p style="color:#ffffff; font-size:17px; font-weight:700;">
# 5. Does tenure influence employee retention?
# </p>
#
# <p style="color:#cfd8dc; line-height:1.8; font-size:15px;">
# Attrition appears to be higher among employees with shorter tenure.
# Employees in their early years at the company are more likely to leave compared to long-term employees.
# This suggests that onboarding experience, early engagement, and career progression planning are critical for improving retention.
# </p>
#
# </div>

# %% [markdown]
# <!-- RECOMMENDATIONS -->
#
# <div align="center"
#      style="background:linear-gradient(135deg,#0f2027,#203a43,#2c5364);
#             padding:30px;
#             border-radius:15px;
#             border:2px solid #00c6ff;
#             margin-top:40px;">
#
# <h2 style="
#     font-size:28px;
#     font-family:Segoe UI, sans-serif;
#     font-weight:900;
#     color:#ffffff;
#     letter-spacing:2px;
#     text-transform:uppercase;
#     text-shadow:
#         0 2px 0 #0a1a22,
#         0 4px 10px rgba(0,0,0,0.6);
# ">
#  RECOMMENDATIONS
# </h2>
#
# </div>
#
# <div style="background-color:#0f2027;
#             padding:25px;
#             border-radius:12px;
#             border:1px solid #00c6ff;
#             margin-top:20px;">
#
# <ul style="color:#cfd8dc; font-size:16px; line-height:1.9;">
#
# <li><b style="color:#ffffff;">Review Compensation Structure:</b>
# Improve salary packages, especially for lower income groups, to reduce financial dissatisfaction.</li>
#
# <li><b style="color:#ffffff;">Department-Specific Retention Strategy:</b>
# Focus on departments with higher attrition by identifying workload issues and managerial challenges.</li>
#
# <li><b style="color:#ffffff;">Enhance Job Satisfaction Programs:</b>
# Implement recognition programs, career growth planning, and employee engagement initiatives.</li>
#
# <li><b style="color:#ffffff;">Promote Work-Life Balance:</b>
# Reduce excessive overtime and encourage flexible work policies to improve employee well-being.</li>
#
# <li><b style="color:#ffffff;">Strengthen Early Employee Engagement:</b>
# Improve onboarding experience and mentorship programs to retain employees during their initial years.</li>
#
# </ul>
#
# </div>
